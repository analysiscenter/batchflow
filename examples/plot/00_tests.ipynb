# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Necessary imports
import sys
import numpy as np

sys.path.append('../..')
from batchflow import plot

# %%
arr = np.random.rand(10, 10)

# %%
data = arr
title = 't'
cmap = 'ocean'
plot(data=data, title=title, cmap=cmap)

# %%
data = [arr, arr]
title = ['t1']
cmap = ['ocean', 'viridis']
plot(data=data, title=title, cmap=cmap)

# %%
data = [arr, arr]
title = ['t', 'y']
cmap = ['ocean', 'viridis']
plot(data=data, title=title, cmap=cmap, combine='separate')

# %%
data = [arr, [arr, arr]]
title = ['t', 'y']
cmap = ['ocean', 'viridis']
plot(data=data, title=title, cmap=cmap)

# %%
data = [arr, [arr, arr]]
title = ['t1', 't2']
cmap = ['ocean', ['viridis', 'Reds']]
plot(data=data, title=title, cmap=cmap)

# %%
data = [arr, [arr, arr > .5]]
title = ['t0', 't1']
cmap = ['ocean', ['viridis', 'firebrick']]
plot(data=data, title=title, cmap=cmap)

# %%
diverse_data = [[np.random.rand(*np.random.randint(2, 10, 2))] for _ in range(np.random.randint(5, 10))]
plot(diverse_data)
